# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó

# %%
a,b= map(int,input().split())
d = (a+b)*2
s = a*b
print('Dien tich hinh chu nhat la', s)
print('Chu vi hinh chu nhat la', d)
# Out:
# Dien tich hinh 63 chu nhat la 63
# Chu vi hinh chu nhat la 32

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
import math
a = float(input())
s = math.pi * a**2
d = 2*math.pi*a
print('dien tich hinh tron la', f"{s:.2f}")
print('chu vi hinh tron la', f"{d:.2f}")
# Out:
# dien tich hinh tron la 153.94
# chu vi hinh tron la 43.98

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình

# %%
import math
a,b,c = map(int,input().split())
if a + b > c and a + c > b and b + c > a:
    if a == b or b == a or c == a:
        d = a + b + c
        s = math.sqrt(d/2*(d/2-a)*(d/2-b)*(d/2-c))
        print('dien tich va chu vi cua tam giac can nay la', f"{s:.2f}" ,d)
    elif a == b == c:
        d = 3*a
        s = (math.sqrt(3)*a**2)/4
        print('dien tich va chu vi cua tam giac deu nay la', f"{s:.2f}" , d) 
    elif a == math.sqrt(b**2 + c**2 ) or b == math.sqrt(a**2 + c**2 ) or c == math.sqrt(a**2 + b**2 ):
        d = a + b + c
        s = math.sqrt(d/2*(d/2-a)*(d/2-b)*(d/2-c))
        print('dien tich va chu vi cua tam giac vuong nay la', f"{s:.2f}" , d)
    else:
        d = a + b + c
        s = math.sqrt(d/2*(d/2-a)*(d/2-b)*(d/2-c))
        print('dien tich va chu vi tam giac thuong nay la', f"{s:.2f}" ,d )
else:
    print('day khong phai cba canh tam giac')
# Out:
# dien tich va chu vi cua tam giac vuong nay la 24.00 24

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a,b = map(int,input().split())
if a == 0:
    if b == 0:
        print('vo so nghiem')
    else:
        print('vo nghiem')
else:
    print('nghiem cua phuong trinh la', -b/a )
# Out:
# vo nghiem

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
import math
a,b,c = map(int,input().split())
if a == 0:
    if b == 0:
        if c == 0:
            print('vo so nghiem')
        else:
            print('vo nghiem')
    else:
        print('nghiem cua phuong trinh la', -c/b)
else:
    delta = b**2 - 4*a*c
    if delta < 0:
        print('vo nghiem')
    elif delta == 0:
        print('phuong trinh co nghiem kep la', -b/(2*a) )
    else :
        x1 = (-b + math.sqrt(delta))/(2*a)
        x2 = (-b - math.sqrt(delta))/(2*a)
        print('nghiem dau tien cua phuong trinh la', x1)
        print('nghiem thu 2 cua phuong trinh la', x2)
# Out:
# phuong trinh co nghiem kep la -2.0

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a,b,c,d= map(int,input().split())
print(max(a,b,c,d))
# Out:
# 9

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím)

# %%
a,b,c,d= map(int,input().split())
print(min(a,b,c,d))
# Out:
# 0

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax  by  m
# cx  dy  n

# %%
a,b,c,d,m,n=map(int,input().split())
A = a*d
D = c*b
C = m*d
F = n*b
if A - D == 0:
    if C - F == 0:
        print("Hệ vô số nghiệm")
    else:
        print("Hệ vô nghiệm")
else:
    x = (C - F) / (A - D)
    y = (m - a*x) / b
    print("x =", x)
    print("y =", y)
# Out:
# x = 2.75
# y = -1.5

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
a = int(input())
b = a//3600
c = (a - b*3600)//60
d =  a - b*3600-c*60
print(f'Cong viec co so thoi gian la {b}:{c}:{d}')
# Out:
# Cong viec co so thoi gian la 1:1:10

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
x0,y0,x1,y1,R=map(int,input().split())
a = (x-x0)**2 + (y - y0)**2
b = R**2
if a > b:
    print('diem nay nam ngoai')
elif a < b:
    print('diem nay nam trong')
else :
    print('diem nay thuoc duong tron')
# Out:
# diem nay nam trong

# %% [markdown]
# Bài 11: Tính x
# y (Với x, y là số thực).

# %%
x,y = map(int,input().split())
print(x**y)
# Out:
# 390625
